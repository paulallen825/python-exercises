# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import pandas as pd
from pydataset import data

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

import warnings
warnings.filterwarnings("ignore")

import acquire

# %%
df_iris = data('iris')

# %%
#First 3 rows
print(df_iris[:3])
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
#number of rows and colums (shape)
df_iris.shape
# Out:
# (150, 5)

# %%
#print the column names
list(df_iris.columns)
# Out:
# ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']

# %%
#print the data type of each column
df_iris.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
#print the summary statistics for each of the numeric variables
df_iris.describe

#scale it 0 -10
# Out:
# <bound method NDFrame.describe of      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# #2 Read the Table1_CustDetails table from the Excel_Exercises.xlsx file into a dataframe named df_excel.

# %%
df_excel = pd.read_csv('/Users/paulneil/codeup-data-science/python-exercises/mytable_customer_details.csv')
df_excel.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                  0     Yes        Yes              1
# 1  0003-MKNFE    Male                  0      No         No              2
# 2  0004-TLHLJ    Male                  0      No         No              1
# 3  0011-IGKFF    Male                  1     Yes         No              1
# 4  0013-EXCHZ  Female                  1     Yes         No              1
#
#    internet_service  contract_type      payment_type  monthly_charges  \
# 0                 1              1      Mailed check             65.6
# 1                 1              0      Mailed check             59.9
# 2                 2              0  Electronic check             73.9
# 3                 2              0  Electronic check             98.0
# 4                 2              0      Mailed check             83.9
#
#    total_charges churn  tenure
# 0         593.30    No    9.04
# ...

# %%
#df_excel_sample = df_excel.head(100)
#df_excel_sample

df_excel_sample = df_excel.loc[0:100].copy()
df_excel_sample
# Out:
#     customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0    0002-ORFBO  Female                  0     Yes        Yes              1
# 1    0003-MKNFE    Male                  0      No         No              2
# 2    0004-TLHLJ    Male                  0      No         No              1
# 3    0011-IGKFF    Male                  1     Yes         No              1
# 4    0013-EXCHZ  Female                  1     Yes         No              1
# 5    0013-MHZWF  Female                  0      No        Yes              1
# 6    0013-SMEOE  Female                  1     Yes         No              1
# 7    0014-BMAQU    Male                  0     Yes         No              2
# 8    0015-UOCOJ  Female                  1      No         No              1
# 9    0016-QLJIS  Female                  0     Yes        Yes              2
# 10   0017-DINOC    Male                  0      No         No              0
# ...

# %%
df_excel.shape
# Out:
# (7049, 13)

# %%
index = df_excel.index
number_of_rows = len(index)
number_of_rows
# Out:
# 7049

# %%
list(df_excel.columns)
# Out:
# ['customer_id',
#  'gender',
#  'is_senior_citizen',
#  'partner',
#  'dependents',
#  'phone_service',
#  'internet_service',
#  'contract_type',
#  'payment_type',
#  'monthly_charges',
#  'total_charges',
#  'churn',
#  'tenure']

# %%
df_excel.columns[0:5]
# Out:
# Index(['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents'], dtype='object')

# %%
df_excel.select_dtypes(include = ['object']).head(5)
# Out:
#   customer_id  gender partner dependents      payment_type churn
# 0  0002-ORFBO  Female     Yes        Yes      Mailed check    No
# 1  0003-MKNFE    Male      No         No      Mailed check    No
# 2  0004-TLHLJ    Male      No         No  Electronic check   Yes
# 3  0011-IGKFF    Male     Yes         No  Electronic check   Yes
# 4  0013-EXCHZ  Female     Yes         No      Mailed check   Yes

# %%
#Compute the range of each of the numeric variables
numerics =df_excel.select_dtypes(include=['float64', 'int64'])
numerics
# Out:
#       is_senior_citizen  phone_service  internet_service  contract_type  \
# 0                     0              1                 1              1
# 1                     0              2                 1              0
# 2                     0              1                 2              0
# 3                     1              1                 2              0
# 4                     1              1                 2              0
# ...                 ...            ...               ...            ...
# 7044                  0              1                 1              1
# 7045                  0              2                 2              0
# 7046                  0              1                 1              0
# 7047                  0              1                 1              2
# 7048                  0              0                 1              2
#
#       monthly_charges  total_charges  tenure
# 0               65.60         593.30    9.04
# ...

# %% [markdown]
# 1. Use the function defined in acquire.py to load the iris data.

# %%
df = acquire.get_iris_data()
df.head()
# Out:
#    species_id species_name  sepal_length  sepal_width  petal_length  \
# 0           1       setosa           5.1          3.5           1.4
# 1           1       setosa           4.9          3.0           1.4
# 2           1       setosa           4.7          3.2           1.3
# 3           1       setosa           4.6          3.1           1.5
# 4           1       setosa           5.0          3.6           1.4
#
#    petal_width
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2

# %%
df = df.drop(columns = ['species_id'])

# %%
df.rename(columns={"species_name": "species"})
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width
# 0        setosa           5.1          3.5           1.4          0.2
# 1        setosa           4.9          3.0           1.4          0.2
# 2        setosa           4.7          3.2           1.3          0.2
# 3        setosa           4.6          3.1           1.5          0.2
# 4        setosa           5.0          3.6           1.4          0.2
# 5        setosa           5.4          3.9           1.7          0.4
# 6        setosa           4.6          3.4           1.4          0.3
# 7        setosa           5.0          3.4           1.5          0.2
# 8        setosa           4.4          2.9           1.4          0.2
# 9        setosa           4.9          3.1           1.5          0.1
# 10       setosa           5.4          3.7           1.5          0.2
# 11       setosa           4.8          3.4           1.6          0.2
# ...

# %%
# use pd.get_dummies. Returns a dataframe
df_dummy = pd.get_dummies(df[['species_name']])
df_dummy.head()
# Out:
#    species_name_setosa  species_name_versicolor  species_name_virginica
# 0                    1                        0                       0
# 1                    1                        0                       0
# 2                    1                        0                       0
# 3                    1                        0                       0
# 4                    1                        0                       0

# %%
# make a prep function:

def prep_iris(df):
    """
    takes in a data from titanic database, cleans the data, splits the data
    in train validate test and imputes the missing values for embark_town. 
    Returns three dataframes train, validate and test.
    """
    
    drop = df.drop(columns = ['species_id'])
    rename=df.rename(columns={"species_name": "species"})
    df_dummy = pd.get_dummies(df[['species_name']])
    df = pd.concat([df, df_dummy],axis = 1)
    
    return drop, rename, df_dummy

# %%
prep_iris(df).head()

# %%
# acquire data again
df = acquire.get_iris_data()
